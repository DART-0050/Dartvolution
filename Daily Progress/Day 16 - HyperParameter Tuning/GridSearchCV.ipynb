# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("./concrete_data.csv")
data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
X = data.iloc[:, :-1].values
Y = data.iloc[:, -1].values.reshape(-1, 1)

# %%
print(np.shape(X))
print(np.shape(Y))
# Out:
# (1030, 8)
# (1030, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2021)

# %% [markdown]
# # XGBoost (Extreme Gradient Boosting)
#
# XGBoost is a powerful machine learning algorithm that excels in predictive modeling.
#
# ---
#
# ## 🌱 What It Does
#
# **Gradient Boosting**:
# XGBoost builds multiple decision trees sequentially, with each tree learning from the errors of its predecessors. It uses gradient descent to minimize prediction errors.
#
# ---
#
# ## 🔑 Key Features
#
# - **High Performance**: Optimized for speed and efficiency
# - **Regularization**: Built-in L1 and L2 regularization to prevent overfitting
# - **Parallel Processing**: Can utilize multiple CPU cores
# - **Handling Missing Values**: Automatically handles missing data
# - **Flexibility**: Supports various objective functions and evaluation metrics
#
# ---
#
# ## 🔍 Use Cases
#
# - Classification (binary and multi-class)
# - Regression
# - Ranking
# - Time-series forecasting
#
# ---
#
# ## ✅ Advantages
#
# - Excellent accuracy
# - Fast computation
# - Robust to overfitting
# - Handles large datasets
# - Provides feature importance ranking
#
# ---
#
#
# > XGBoost is widely used in machine learning competitions and real-world applications due to its superior performance and efficiency.

# %%
#Defining the base model using XGBoost

from xgboost import XGBRegressor
xgb_model = XGBRegressor(random_state=2021)

# %% [markdown]
# ## 🌟 Common XGBoost Hyperparameters (for `XGBClassifier`)
#
# ---
#
# ### ✅ 1. `n_estimators`
#
# > **Number of boosting rounds / trees**
#
# * Default: 100
# * Higher → more trees, better fit, but slower
# * Works with `learning_rate`: small LR → need more trees
#
# ---
#
# ### ✅ 2. `learning_rate` (aka `eta`)
#
# > **How much each tree contributes to the final prediction**
#
# * Default: 0.3
# * Smaller = slower learning, better generalization
# * Typical: `0.01` to `0.1`
#
# ✅ Rule of thumb:
#
# > Use `learning_rate = 0.01` with `n_estimators = 500+` for strong models
#
# ---
#
# ### ✅ 3. `max_depth`
#
# > **Maximum depth of each tree**
#
# * Controls how complex a tree is
# * Default: 6
# * Lower → less overfitting, Higher → more expressive
#
# 📌 Try: `[3, 6, 9]`
#
# ---
#
# ### ✅ 4. `subsample`
#
# > **Fraction of training rows to use for each tree**
#
# * Range: `0.5` to `1.0`
# * Default: 1.0
# * Lower values help regularize (avoid overfitting)
#
# 📌 Try: `0.8` or `0.9`
#
# ---
#
# ### ✅ 5. `colsample_bytree`
#
# > **Fraction of features (columns) to use per tree**
#
# * Default: 1.0
# * Like `subsample`, but for columns
# * Helps diversify trees
#
# 📌 Try: `0.6`, `0.8`, `1.0`
#
# ---
#
# ### ✅ 6. `gamma`
#
# > **Minimum loss reduction to split a node**
#
# * Default: 0
# * Higher → model is more conservative
# * Helps prune branches in trees
#
# 📌 Try: `0`, `0.1`, `0.5`
#
# ---
#
# ### ✅ 7. `min_child_weight`
#
# > **Minimum sum of weights required in a child node**
#
# * Default: 1
# * Higher = more conservative splits
# * A form of regularization (reduces overfitting)
#
# 📌 Try: `1`, `5`, `10`
#
# ---
#
# ### ✅ 8. `objective`
#
# > **Defines the type of prediction task**
#
# * For binary classification → `"binary:logistic"` ✅
# * For multiclass → `"multi:softprob"`
# * For regression → `"reg:squarederror"`
#
# ---
#
# ### ✅ 9. `eval_metric`
#
# > **What to optimize during training**
#
# * Binary: `"logloss"`, `"error"`, `"auc"`
# * Multi-class: `"mlogloss"`, `"merror"`
# * Regression: `"rmse"`, `"mae"`
#
# 📌 Example:
#
# ```python
# XGBClassifier(eval_metric='logloss')
# ```
#
# ---
#
# ### ✅ 10. `scale_pos_weight`
#
# > **Helps with imbalanced datasets** (e.g. 90% class 0, 10% class 1)
#
# * \= (# of class 0 examples) / (# of class 1 examples)
#
# 📌 Try this if you have class imbalance!
#
# ---
#
# ## 🔁 Regularization Parameters
#
# | Parameter | Purpose                   | Typical Values |
# | --------- | ------------------------- | -------------- |
# | `gamma`   | Prune trees               | 0 to 5         |
# | `lambda`  | L2 regularization (Ridge) | 0 to 1         |
# | `alpha`   | L1 regularization (Lasso) | 0 to 1         |
#
# ---
#
# ### 🛠 Sample Model Setup
#
# ```python
# from xgboost import XGBClassifier
#
# model = XGBClassifier(
#     n_estimators=200,
#     learning_rate=0.05,
#     max_depth=4,
#     subsample=0.8,
#     colsample_bytree=0.8,
#     gamma=0.1,
#     min_child_weight=1,
#     objective='binary:logistic',
#     eval_metric='auc',
#     use_label_encoder=False
# )
# ```

# %%
search_space = {
    'n_estimators': [100, 200, 500],
    'max_depth': [3,6,9],
    'gamma' : [0.01,0.1],
    "learning_rate" : [0.001,0.01,0.1,1]
}

# %%
from sklearn.model_selection import GridSearchCV

GS = GridSearchCV(estimator = xgb_model,
                    param_grid = search_space,
                    scoring = ['r2','neg_mean_absolute_error'],
                    cv = 5, #cross validation
                    refit = 'r2', #refit the model with the best parameters
                    verbose = 4)  #to tell how much info should be printed

# %%
GS.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-12.564) r2: (test=0.112) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-12.236) r2: (test=0.103) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-13.121) r2: (test=0.119) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-12.548) r2: (test=0.106) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-13.274) r2: (test=0.108) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-11.879) r2: (test=0.211) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-11.567) r2: (test=0.195) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-12.377) r2: (test=0.217) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-11.870) r2: (test=0.198) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-12.505) r2: (test=0.205) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-10.096) r2: (test=0.433) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-9.979) r2: (test=0.398) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-10.580) r2: (test=0.424) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-10.208) r2: (test=0.402) total time=   0.3s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-10.675) r2: (test=0.413) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-12.324) r2: (test=0.141) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-12.050) r2: (test=0.124) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-12.897) r2: (test=0.153) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-12.416) r2: (test=0.138) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-13.050) r2: (test=0.139) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-11.458) r2: (test=0.262) total time=   0.3s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-11.218) r2: (test=0.234) total time=   0.3s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-11.943) r2: (test=0.276) total time=   0.3s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-11.588) r2: (test=0.254) total time=   0.3s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-12.092) r2: (test=0.256) total time=   0.3s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-9.294) r2: (test=0.518) total time=   0.8s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-9.234) r2: (test=0.469) total time=   0.7s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-9.630) r2: (test=0.530) total time=   0.8s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-9.468) r2: (test=0.502) total time=   0.8s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-9.824) r2: (test=0.505) total time=   0.8s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-12.241) r2: (test=0.147) total time=   0.3s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-12.031) r2: (test=0.129) total time=   0.3s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-12.821) r2: (test=0.159) total time=   0.3s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-12.392) r2: (test=0.140) total time=   0.3s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-13.013) r2: (test=0.143) total time=   0.3s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-11.321) r2: (test=0.272) total time=   0.7s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-11.195) r2: (test=0.238) total time=   1.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-11.804) r2: (test=0.288) total time=   0.7s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-11.546) r2: (test=0.257) total time=   0.9s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-12.043) r2: (test=0.263) total time=   0.9s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-9.087) r2: (test=0.528) total time=   2.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-9.085) r2: (test=0.474) total time=   2.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-9.421) r2: (test=0.544) total time=   1.8s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-9.445) r2: (test=0.506) total time=   1.8s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-9.811) r2: (test=0.507) total time=   2.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-8.007) r2: (test=0.641) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-8.132) r2: (test=0.592) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-8.530) r2: (test=0.618) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-8.664) r2: (test=0.585) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-8.681) r2: (test=0.600) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-5.889) r2: (test=0.804) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-6.245) r2: (test=0.754) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-6.218) r2: (test=0.792) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-6.655) r2: (test=0.751) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-6.915) r2: (test=0.741) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-3.909) r2: (test=0.903) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-4.614) r2: (test=0.866) total time=   0.3s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-4.343) r2: (test=0.893) total time=   0.3s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-4.782) r2: (test=0.861) total time=   0.5s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-5.167) r2: (test=0.836) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-6.820) r2: (test=0.737) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-7.116) r2: (test=0.674) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-7.094) r2: (test=0.743) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-7.011) r2: (test=0.720) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-7.301) r2: (test=0.712) total time=   0.5s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-4.490) r2: (test=0.869) total time=   0.6s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-5.022) r2: (test=0.822) total time=   0.5s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-4.741) r2: (test=0.872) total time=   0.6s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-4.911) r2: (test=0.852) total time=   0.5s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-5.324) r2: (test=0.834) total time=   0.5s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-3.185) r2: (test=0.914) total time=   1.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-3.650) r2: (test=0.893) total time=   1.5s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-3.453) r2: (test=0.915) total time=   1.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-3.546) r2: (test=0.903) total time=   1.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-4.127) r2: (test=0.871) total time=   1.6s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-6.673) r2: (test=0.735) total time=   0.7s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-6.838) r2: (test=0.681) total time=   0.6s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-6.761) r2: (test=0.755) total time=   0.7s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-6.949) r2: (test=0.720) total time=   1.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-7.290) r2: (test=0.714) total time=   1.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-4.359) r2: (test=0.863) total time=   2.6s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-4.836) r2: (test=0.819) total time=   1.6s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-4.395) r2: (test=0.883) total time=   2.6s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-4.626) r2: (test=0.862) total time=   2.6s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-5.145) r2: (test=0.844) total time=   2.5s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.214) r2: (test=0.897) total time=   5.7s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.688) r2: (test=0.878) total time=   4.5s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.444) r2: (test=0.916) total time=   2.9s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.442) r2: (test=0.902) total time=   2.6s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-4.023) r2: (test=0.879) total time=   2.7s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-3.439) r2: (test=0.924) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-4.046) r2: (test=0.889) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-3.760) r2: (test=0.916) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-3.925) r2: (test=0.896) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-4.500) r2: (test=0.863) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-3.056) r2: (test=0.938) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-3.672) r2: (test=0.901) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-3.410) r2: (test=0.926) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-3.462) r2: (test=0.913) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-4.068) r2: (test=0.876) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-2.728) r2: (test=0.949) total time=   0.3s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-3.371) r2: (test=0.911) total time=   0.3s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-3.123) r2: (test=0.932) total time=   0.3s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-3.117) r2: (test=0.924) total time=   0.3s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-3.714) r2: (test=0.889) total time=   0.3s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-2.964) r2: (test=0.919) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-3.360) r2: (test=0.906) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-3.212) r2: (test=0.925) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-3.286) r2: (test=0.913) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-3.926) r2: (test=0.877) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-2.858) r2: (test=0.923) total time=   0.3s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-3.251) r2: (test=0.910) total time=   0.3s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-3.092) r2: (test=0.925) total time=   0.3s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-3.073) r2: (test=0.920) total time=   0.3s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-3.826) r2: (test=0.881) total time=   0.3s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-2.839) r2: (test=0.924) total time=   0.6s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-3.181) r2: (test=0.913) total time=   0.8s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-3.051) r2: (test=0.924) total time=   0.6s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-3.033) r2: (test=0.921) total time=   0.6s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-3.767) r2: (test=0.884) total time=   0.6s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-3.117) r2: (test=0.902) total time=   0.5s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-3.657) r2: (test=0.877) total time=   0.5s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-3.399) r2: (test=0.917) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-3.398) r2: (test=0.901) total time=   0.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-3.931) r2: (test=0.883) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-3.107) r2: (test=0.902) total time=   0.6s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-3.651) r2: (test=0.877) total time=   0.5s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-3.389) r2: (test=0.918) total time=   0.5s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-3.392) r2: (test=0.901) total time=   0.5s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-3.926) r2: (test=0.883) total time=   0.5s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.107) r2: (test=0.902) total time=   0.7s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.651) r2: (test=0.877) total time=   0.9s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.389) r2: (test=0.918) total time=   0.7s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.392) r2: (test=0.901) total time=   0.6s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.926) r2: (test=0.883) total time=   0.6s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-3.205) r2: (test=0.920) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-4.019) r2: (test=0.876) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-3.618) r2: (test=0.888) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-3.647) r2: (test=0.895) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-4.402) r2: (test=0.814) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-3.029) r2: (test=0.925) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-3.869) r2: (test=0.884) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-3.611) r2: (test=0.888) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-3.451) r2: (test=0.899) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-4.502) r2: (test=0.808) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-3.073) r2: (test=0.924) total time=   0.3s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-3.965) r2: (test=0.880) total time=   0.3s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-3.619) r2: (test=0.886) total time=   0.3s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-3.511) r2: (test=0.898) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-4.486) r2: (test=0.809) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-3.507) r2: (test=0.888) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-4.933) r2: (test=0.766) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-4.298) r2: (test=0.864) total time=   0.0s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-4.351) r2: (test=0.845) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-4.822) r2: (test=0.830) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-3.507) r2: (test=0.888) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-4.933) r2: (test=0.766) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-4.298) r2: (test=0.864) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-4.351) r2: (test=0.845) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-4.822) r2: (test=0.830) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-3.507) r2: (test=0.888) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-4.933) r2: (test=0.766) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-4.298) r2: (test=0.864) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-4.351) r2: (test=0.845) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-4.822) r2: (test=0.830) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-3.979) r2: (test=0.870) total time=   0.0s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-4.660) r2: (test=0.812) total time=   0.0s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-4.082) r2: (test=0.882) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-4.803) r2: (test=0.811) total time=   0.0s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-4.983) r2: (test=0.784) total time=   0.0s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-3.979) r2: (test=0.870) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-4.660) r2: (test=0.812) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-4.082) r2: (test=0.882) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-4.803) r2: (test=0.811) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-4.983) r2: (test=0.784) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.979) r2: (test=0.870) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-4.660) r2: (test=0.812) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-4.082) r2: (test=0.882) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-4.803) r2: (test=0.811) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-4.983) r2: (test=0.784) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-12.564) r2: (test=0.112) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-12.236) r2: (test=0.103) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-13.121) r2: (test=0.119) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-12.548) r2: (test=0.106) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-13.274) r2: (test=0.108) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-11.879) r2: (test=0.211) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-11.567) r2: (test=0.195) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-12.377) r2: (test=0.217) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-11.870) r2: (test=0.198) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-12.505) r2: (test=0.205) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-10.096) r2: (test=0.433) total time=   0.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-9.979) r2: (test=0.398) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-10.580) r2: (test=0.424) total time=   0.3s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-10.208) r2: (test=0.402) total time=   0.3s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-10.675) r2: (test=0.413) total time=   0.3s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-12.324) r2: (test=0.141) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-12.050) r2: (test=0.124) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-12.897) r2: (test=0.153) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-12.416) r2: (test=0.138) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-13.050) r2: (test=0.139) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-11.458) r2: (test=0.262) total time=   0.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-11.218) r2: (test=0.234) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-11.943) r2: (test=0.276) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-11.588) r2: (test=0.254) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-12.092) r2: (test=0.256) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-9.295) r2: (test=0.518) total time=   1.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-9.233) r2: (test=0.469) total time=   1.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-9.629) r2: (test=0.530) total time=   1.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-9.469) r2: (test=0.502) total time=   1.0s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-9.824) r2: (test=0.505) total time=   1.0s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-12.241) r2: (test=0.147) total time=   0.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-12.031) r2: (test=0.129) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-12.821) r2: (test=0.159) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-12.393) r2: (test=0.140) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-13.013) r2: (test=0.143) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-11.321) r2: (test=0.272) total time=   0.9s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-11.195) r2: (test=0.238) total time=   0.9s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-11.804) r2: (test=0.288) total time=   0.9s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-11.547) r2: (test=0.257) total time=   0.9s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-12.043) r2: (test=0.263) total time=   0.9s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-9.087) r2: (test=0.528) total time=   2.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-9.085) r2: (test=0.474) total time=   2.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-9.421) r2: (test=0.544) total time=   2.3s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-9.445) r2: (test=0.506) total time=   2.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-9.811) r2: (test=0.507) total time=   2.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-8.007) r2: (test=0.641) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-8.132) r2: (test=0.592) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-8.530) r2: (test=0.618) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-8.664) r2: (test=0.585) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-8.681) r2: (test=0.600) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-5.889) r2: (test=0.804) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-6.245) r2: (test=0.754) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-6.218) r2: (test=0.792) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-6.655) r2: (test=0.751) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-6.915) r2: (test=0.741) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-3.909) r2: (test=0.903) total time=   0.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-4.614) r2: (test=0.866) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-4.342) r2: (test=0.893) total time=   0.3s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-4.782) r2: (test=0.861) total time=   0.3s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-5.167) r2: (test=0.836) total time=   0.3s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-6.820) r2: (test=0.737) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-7.115) r2: (test=0.674) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-7.102) r2: (test=0.742) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-7.010) r2: (test=0.720) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-7.302) r2: (test=0.712) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-4.488) r2: (test=0.869) total time=   0.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-5.020) r2: (test=0.822) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-4.755) r2: (test=0.871) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-4.936) r2: (test=0.851) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-5.327) r2: (test=0.833) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-3.189) r2: (test=0.914) total time=   1.0s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-3.690) r2: (test=0.892) total time=   1.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-3.463) r2: (test=0.915) total time=   1.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-3.525) r2: (test=0.904) total time=   1.0s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-4.090) r2: (test=0.872) total time=   1.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-6.675) r2: (test=0.735) total time=   0.5s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-6.845) r2: (test=0.680) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-6.763) r2: (test=0.755) total time=   0.6s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-6.953) r2: (test=0.720) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-7.294) r2: (test=0.713) total time=   0.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-4.376) r2: (test=0.862) total time=   1.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-4.849) r2: (test=0.818) total time=   1.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-4.393) r2: (test=0.883) total time=   1.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-4.631) r2: (test=0.862) total time=   1.0s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-5.125) r2: (test=0.844) total time=   1.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.169) r2: (test=0.899) total time=   2.7s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.702) r2: (test=0.878) total time=   2.8s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.403) r2: (test=0.918) total time=   2.8s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.418) r2: (test=0.903) total time=   3.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.993) r2: (test=0.879) total time=   2.8s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-3.439) r2: (test=0.924) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-4.046) r2: (test=0.889) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-3.760) r2: (test=0.916) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-3.925) r2: (test=0.896) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-4.500) r2: (test=0.863) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-3.053) r2: (test=0.938) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-3.660) r2: (test=0.902) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-3.447) r2: (test=0.926) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-3.462) r2: (test=0.913) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-4.068) r2: (test=0.876) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-2.684) r2: (test=0.949) total time=   0.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-3.353) r2: (test=0.914) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-3.089) r2: (test=0.934) total time=   0.3s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-3.126) r2: (test=0.923) total time=   0.3s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-3.731) r2: (test=0.888) total time=   0.3s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-2.968) r2: (test=0.919) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-3.390) r2: (test=0.905) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-3.182) r2: (test=0.925) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-3.202) r2: (test=0.916) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-3.925) r2: (test=0.877) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-2.844) r2: (test=0.923) total time=   0.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-3.252) r2: (test=0.911) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-3.056) r2: (test=0.926) total time=   0.3s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-3.063) r2: (test=0.922) total time=   0.3s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-3.822) r2: (test=0.881) total time=   0.3s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-2.844) r2: (test=0.923) total time=   0.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-3.252) r2: (test=0.911) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-3.056) r2: (test=0.926) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-3.063) r2: (test=0.922) total time=   0.5s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-3.822) r2: (test=0.881) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-3.097) r2: (test=0.900) total time=   0.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-3.716) r2: (test=0.874) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-3.371) r2: (test=0.920) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-3.390) r2: (test=0.902) total time=   0.3s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-3.932) r2: (test=0.882) total time=   0.3s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-3.097) r2: (test=0.900) total time=   0.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-3.716) r2: (test=0.874) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-3.371) r2: (test=0.920) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-3.390) r2: (test=0.902) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-3.932) r2: (test=0.882) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.097) r2: (test=0.900) total time=   0.5s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.716) r2: (test=0.874) total time=   0.5s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.371) r2: (test=0.920) total time=   0.5s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.390) r2: (test=0.902) total time=   0.5s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.932) r2: (test=0.882) total time=   0.5s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-3.323) r2: (test=0.918) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-4.035) r2: (test=0.875) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-3.613) r2: (test=0.890) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-3.647) r2: (test=0.895) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_mean_absolute_error: (test=-4.404) r2: (test=0.818) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-3.196) r2: (test=0.920) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-4.021) r2: (test=0.875) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-3.636) r2: (test=0.883) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-3.487) r2: (test=0.897) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_mean_absolute_error: (test=-4.352) r2: (test=0.818) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-3.196) r2: (test=0.920) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-4.021) r2: (test=0.875) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-3.638) r2: (test=0.884) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-3.487) r2: (test=0.897) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_mean_absolute_error: (test=-4.336) r2: (test=0.818) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-3.518) r2: (test=0.888) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-4.547) r2: (test=0.787) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-4.221) r2: (test=0.863) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-4.329) r2: (test=0.849) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_mean_absolute_error: (test=-4.857) r2: (test=0.823) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-3.518) r2: (test=0.888) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-4.547) r2: (test=0.787) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-4.221) r2: (test=0.863) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-4.329) r2: (test=0.849) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_mean_absolute_error: (test=-4.857) r2: (test=0.823) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-3.518) r2: (test=0.888) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-4.547) r2: (test=0.787) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-4.221) r2: (test=0.863) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-4.329) r2: (test=0.849) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_mean_absolute_error: (test=-4.857) r2: (test=0.823) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-3.819) r2: (test=0.873) total time=   0.0s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-4.577) r2: (test=0.822) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-4.255) r2: (test=0.867) total time=   0.0s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-4.841) r2: (test=0.814) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_mean_absolute_error: (test=-5.153) r2: (test=0.779) total time=   0.0s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-3.819) r2: (test=0.873) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-4.577) r2: (test=0.822) total time=   0.0s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-4.255) r2: (test=0.867) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-4.841) r2: (test=0.814) total time=   0.0s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_mean_absolute_error: (test=-5.153) r2: (test=0.779) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-3.819) r2: (test=0.873) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-4.577) r2: (test=0.822) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-4.255) r2: (test=0.867) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-4.841) r2: (test=0.814) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_mean_absolute_error: (test=-5.153) r2: (test=0.779) total time=   0.1s
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, feature_weights=None,
#                                     gamma=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None, ...),
#              param_grid={'gamma': [0.01, 0.1],
#                          'learning_rate': [0.001, 0.01, 0.1, 1],
#                          'max_depth': [3, 6, 9],
#                          'n_estimators': [100, 200, 500]},
#              refit='r2', scoring=['r2', 'neg_mean_absolute_error'], verbose=4)

# %%
print(GS.best_params_)
# Out:
# {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}

# %%
print(GS.best_score_)
# Out:
# 0.921563136246513

# %%
df = pd.DataFrame(GS.cv_results_)
df = df.sort_values("rank_test_r2")
df.to_csv("cv_results.csv")
